# %% [markdown]
# ## Exercise 3: Part 1

# %% [markdown]
# *In this task, we define semantic textual similarity (STS) as a supervised regression task in which the semantic similarity
# of two pieces of text (typically sentences) should be determined.*

# %%
import numpy as np
import os

# %% [markdown]
# *We build a reader function for the labeled data sets, which for a given filename returns a list of scores, a list of
# first sentences, and a list of second sentences.*

# %%
def dataset_reader(file_path):
    """
    Reads the input vectors and the corresponding labels from a file
    @param file_path: String / path to files
    @return: two numpy arrays / 1. input vectors, 2. labels
    """
    vectors = []
    sentences1 = []
    sentences2 = []
    with open(file_path, "r",encoding='utf8') as f:
        for line in f:
            lines = line.replace('\t','\n').split('\n')
            
            sentences1.append(lines[1])
            sentences2.append(lines[2])
            # Convert string values to float and add bias
            vector = np.array(lines[0].split(), dtype='float')
            vectors.append(vector)
        
    return np.array(vectors,dtype=float), sentences1, sentences2

# %%
scores_dev, sentences1_dev, sentences2_dev = dataset_reader('data-dev.txt')
scores_train, sentences1_train, sentences2_train = dataset_reader('data-train.txt')

# %%
print('first sentence pair: {} {} '.format(sentences1_train[0],sentences2_train[0]))
print('similarity score of first sentence pair: {}'.format(scores_train[0]))
# Out:
# first sentence pair: A brown dog is running through the field. a brown dog with his tongue wagging as he runs through a field
# similarity score of first sentence pair: [0.8]

# %% [markdown]
# *We build a function to read in the first 40000 lines of the 300-dim vector embeddings*

# %%
def load_vectors(fname):
    fin = open(fname, 'r', encoding='utf-8', newline='\n', errors='ignore')
    n, d = map(int, fin.readline().split())
    data = {}
    count=0
    for line in fin:
        count+=1
        if count==40001:
            break
        tokens = line.rstrip().split(' ')
        data[tokens[0]] = list(map(float, tokens[1:]))
    return data

# %%
wiki_vector = load_vectors('wiki-news-300d-1M.vec')

# %% [markdown]
# *We tokenize every sentence with the word_tokenize function of nltk package*

# %%
from nltk.tokenize import word_tokenize

# %%
def tokenize(sentences):
    token_sent = []
    for sentence in sentences:
        token_sent.append(word_tokenize(sentence))
    
    return token_sent

# %%
token_sent1_train = tokenize(sentences1_train)
token_sent2_train = tokenize(sentences2_train)

# %%
token_sent1_dev = tokenize(sentences1_dev)
token_sent2_dev = tokenize(sentences2_dev)

# %%
print('1st sentence:{}'.format(token_sent1_train[0]))
# Out:
# 1st sentence:['A', 'brown', 'dog', 'is', 'running', 'through', 'the', 'field', '.']

# %%
len(wiki_vector)
# Out:
# 40000

# %% [markdown]
# *We map every tokens with the 300-dim vector from the embeddings*

# %%
def map_tokens(tokenized_sent):
    embedding_vectors = {}
    for tokenized_sent in tokenized_sent:
        for tokens in tokenized_sent:
            if tokens in wiki_vector.keys():
                embedding_vectors[tokens] = wiki_vector.get(tokens)
            else:
                embedding_vectors[tokens] = np.zeros((300))
    return embedding_vectors

# %%
embedding_vectors_sent1 = map_tokens(token_sent1_train)
embedding_vectors_sent2 = map_tokens(token_sent2_train)

# %%
embedding_sent1_dev = map_tokens(token_sent1_dev)
embedding_sent2_dev = map_tokens(token_sent2_dev)

# %% [markdown]
# *We average the embeddings to make every line item to be of the same size*

# %%
def avg_embeddings(tokenized_sentences,embedding_vectors):
    avg_embeddings = []
    for tokenized_sent in tokenized_sentences:
        
        sum_vec = np.zeros((300),dtype=float)
        for tokens in tokenized_sent:
            sum_vec =  sum_vec + embedding_vectors.get(tokens)
            
        avg_embeddings.append(sum_vec/len(tokenized_sent))
    
    return np.array(avg_embeddings)

# %%
avg_vectors_sent1 = avg_embeddings(token_sent1_train,embedding_vectors_sent1)
avg_vectors_sent2 = avg_embeddings(token_sent2_train,embedding_vectors_sent2)

# %%
avg_vectors_sent1_dev = avg_embeddings(token_sent1_dev,embedding_sent1_dev)
avg_vectors_sent2_dev = avg_embeddings(token_sent2_dev,embedding_sent2_dev)

# %%
print('averaged embeddings of 1st sequence:{}'.format(avg_vectors_sent1[0][:20]))
# Out:
# averaged embeddings of 1st sequence:[-0.04035556  0.04834444 -0.02134444  0.05437778 -0.04855556 -0.02447778
#  -0.02275556 -0.00113333  0.00976667  0.01081111  0.03703333  0.01817778
#   0.05385556  0.05241111  0.03544444 -0.00903333  0.02505556  0.04105556
#  -0.02614444  0.01518889]

# %% [markdown]
# *We build a neural network with two hidden layers and dropout layer using the keras library and print the mean squared error*

# %%
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, Concatenate

input1 = Input(shape=(300,))
input2 = Input(shape=(300,))
merged = Concatenate(axis=1)([input1, input2])
dense1 = Dense(300, input_dim=2, activation='relu', use_bias=True)(merged)
dropout = Dropout(0.3)(dense1)
output = Dense(1, activation='sigmoid')(dropout)
model = Model(inputs=[input1,input2], outputs=output)

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 300)]        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 300)]        0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600)          0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 300)          180300      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 300)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            301         dropout_1[0][0]
# ==================================================================================================
# Total params: 180,601
# Trainable params: 180,601
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='MeanSquaredError',
            optimizer='adam', metrics=['MeanSquaredError'])

model.fit([avg_vectors_sent1,avg_vectors_sent2],scores_train,epochs=300,batch_size=100,verbose=2)

#model.evaluate([avg_vectors_sent1,avg_vectors_sent2],scores_train)
# Out:
# Epoch 1/300
# 30/30 - 0s - loss: 0.0901 - mean_squared_error: 0.0901
# Epoch 2/300
# 30/30 - 0s - loss: 0.0858 - mean_squared_error: 0.0858
# Epoch 3/300
# 30/30 - 0s - loss: 0.0821 - mean_squared_error: 0.0821
# Epoch 4/300
# 30/30 - 0s - loss: 0.0796 - mean_squared_error: 0.0796
# Epoch 5/300
# 30/30 - 0s - loss: 0.0768 - mean_squared_error: 0.0768
# Epoch 6/300
# 30/30 - 0s - loss: 0.0747 - mean_squared_error: 0.0747
# Epoch 7/300
# 30/30 - 0s - loss: 0.0716 - mean_squared_error: 0.0716
# Epoch 8/300
# 30/30 - 0s - loss: 0.0695 - mean_squared_error: 0.0695
# Epoch 9/300
# 30/30 - 0s - loss: 0.0670 - mean_squared_error: 0.0670
# Epoch 10/300
# 30/30 - 0s - loss: 0.0643 - mean_squared_error: 0.0643
# Epoch 11/300
# 30/30 - 0s - loss: 0.0611 - mean_squared_error: 0.0611
# Epoch 12/300
# 30/30 - 0s - loss: 0.0585 - mean_squared_error: 0.0585
# Epoch 13/300
# 30/30 - 0s - loss: 0.0570 - mean_squared_error: 0.0570
# Epoch 14/300
# 30/30 - 0s - loss: 0.0538 - mean_squared_error: 0.0538
# Epoch 15/300
# 30/30 - 0s - loss: 0.0516 - mean_squared_error: 0.0516
# Epoch 16/300
# 30/30 - 0s - loss: 0.0490 - mean_squared_error: 0.0490
# Epoch 17/300
# 30/30 - 0s - loss: 0.0462 - mean_squared_error: 0.0462
# Epoch 18/300
# 30/30 - 0s - loss: 0.0438 - mean_squared_error: 0.0438
# Epoch 19/300
# 30/30 - 0s - loss: 0.0416 - mean_squared_error: 0.0416
# Epoch 20/300
# 30/30 - 0s - loss: 0.0406 - mean_squared_error: 0.0406
# Epoch 21/300
# 30/30 - 0s - loss: 0.0381 - mean_squared_error: 0.0381
# Epoch 22/300
# 30/30 - 0s - loss: 0.0366 - mean_squared_error: 0.0366
# Epoch 23/300
# 30/30 - 0s - loss: 0.0342 - mean_squared_error: 0.0342
# Epoch 24/300
# 30/30 - 0s - loss: 0.0329 - mean_squared_error: 0.0329
# Epoch 25/300
# 30/30 - 0s - loss: 0.0316 - mean_squared_error: 0.0316
# Epoch 26/300
# 30/30 - 0s - loss: 0.0292 - mean_squared_error: 0.0292
# Epoch 27/300
# 30/30 - 0s - loss: 0.0285 - mean_squared_error: 0.0285
# Epoch 28/300
# 30/30 - 0s - loss: 0.0295 - mean_squared_error: 0.0295
# Epoch 29/300
# 30/30 - 0s - loss: 0.0267 - mean_squared_error: 0.0267
# Epoch 30/300
# 30/30 - 0s - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 31/300
# 30/30 - 0s - loss: 0.0242 - mean_squared_error: 0.0242
# Epoch 32/300
# 30/30 - 0s - loss: 0.0231 - mean_squared_error: 0.0231
# Epoch 33/300
# 30/30 - 0s - loss: 0.0220 - mean_squared_error: 0.0220
# Epoch 34/300
# 30/30 - 0s - loss: 0.0213 - mean_squared_error: 0.0213
# Epoch 35/300
# 30/30 - 0s - loss: 0.0204 - mean_squared_error: 0.0204
# Epoch 36/300
# 30/30 - 0s - loss: 0.0197 - mean_squared_error: 0.0197
# Epoch 37/300
# 30/30 - 0s - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 38/300
# 30/30 - 0s - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 39/300
# 30/30 - 0s - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 40/300
# 30/30 - 0s - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 41/300
# 30/30 - 0s - loss: 0.0165 - mean_squared_error: 0.0165
# Epoch 42/300
# 30/30 - 0s - loss: 0.0159 - mean_squared_error: 0.0159
# Epoch 43/300
# 30/30 - 0s - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 44/300
# 30/30 - 0s - loss: 0.0154 - mean_squared_error: 0.0154
# Epoch 45/300
# 30/30 - 0s - loss: 0.0149 - mean_squared_error: 0.0149
# Epoch 46/300
# 30/30 - 0s - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 47/300
# 30/30 - 0s - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 48/300
# 30/30 - 0s - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 49/300
# 30/30 - 0s - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 50/300
# 30/30 - 0s - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 51/300
# 30/30 - 0s - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 52/300
# 30/30 - 0s - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 53/300
# 30/30 - 0s - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 54/300
# 30/30 - 0s - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 55/300
# 30/30 - 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 56/300
# 30/30 - 0s - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 57/300
# 30/30 - 0s - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 58/300
# 30/30 - 0s - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 59/300
# 30/30 - 0s - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 60/300
# 30/30 - 0s - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 61/300
# 30/30 - 0s - loss: 0.0108 - mean_squared_error: 0.0108
# Epoch 62/300
# 30/30 - 0s - loss: 0.0108 - mean_squared_error: 0.0108
# Epoch 63/300
# 30/30 - 0s - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 64/300
# 30/30 - 0s - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 65/300
# 30/30 - 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 66/300
# 30/30 - 0s - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 67/300
# 30/30 - 0s - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 68/300
# 30/30 - 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 69/300
# 30/30 - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 70/300
# 30/30 - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 71/300
# 30/30 - 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 72/300
# 30/30 - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 73/300
# 30/30 - 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 74/300
# 30/30 - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 75/300
# 30/30 - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 76/300
# 30/30 - 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 77/300
# 30/30 - 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 78/300
# 30/30 - 0s - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 79/300
# 30/30 - 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 80/300
# 30/30 - 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 81/300
# 30/30 - 0s - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 82/300
# 30/30 - 0s - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 83/300
# 30/30 - 0s - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 84/300
# 30/30 - 0s - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 85/300
# 30/30 - 0s - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 86/300
# 30/30 - 0s - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 87/300
# 30/30 - 0s - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 88/300
# 30/30 - 0s - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 89/300
# 30/30 - 0s - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 90/300
# 30/30 - 0s - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 91/300
# 30/30 - 0s - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 92/300
# 30/30 - 0s - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 93/300
# 30/30 - 0s - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 94/300
# 30/30 - 0s - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 95/300
# 30/30 - 0s - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 96/300
# 30/30 - 0s - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 97/300
# 30/30 - 0s - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 98/300
# 30/30 - 0s - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 99/300
# 30/30 - 0s - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 100/300
# 30/30 - 0s - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 101/300
# 30/30 - 0s - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 102/300
# 30/30 - 0s - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 103/300
# 30/30 - 0s - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 104/300
# 30/30 - 0s - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 105/300
# 30/30 - 0s - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 106/300
# 30/30 - 0s - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 107/300
# 30/30 - 0s - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 108/300
# 30/30 - 0s - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 109/300
# 30/30 - 0s - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 110/300
# 30/30 - 0s - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 111/300
# 30/30 - 0s - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 112/300
# 30/30 - 0s - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 113/300
# 30/30 - 0s - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 114/300
# 30/30 - 0s - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 115/300
# 30/30 - 0s - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 116/300
# 30/30 - 0s - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 117/300
# 30/30 - 0s - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 118/300
# 30/30 - 0s - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 119/300
# 30/30 - 0s - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 120/300
# 30/30 - 0s - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 121/300
# 30/30 - 0s - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 122/300
# 30/30 - 0s - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 123/300
# 30/30 - 0s - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 124/300
# 30/30 - 0s - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 125/300
# 30/30 - 0s - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 126/300
# 30/30 - 0s - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 127/300
# 30/30 - 0s - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 128/300
# 30/30 - 0s - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 129/300
# 30/30 - 0s - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 130/300
# 30/30 - 0s - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 131/300
# 30/30 - 0s - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 132/300
# 30/30 - 0s - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 133/300
# 30/30 - 0s - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 134/300
# 30/30 - 0s - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 135/300
# 30/30 - 0s - loss: 0.0068 - mean_squared_error: 0.0068
# Epoch 136/300
# 30/30 - 0s - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 137/300
# 30/30 - 0s - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 138/300
# 30/30 - 0s - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 139/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 140/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 141/300
# 30/30 - 0s - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 142/300
# 30/30 - 0s - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 143/300
# 30/30 - 0s - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 144/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 145/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 146/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 147/300
# 30/30 - 0s - loss: 0.0068 - mean_squared_error: 0.0068
# Epoch 148/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 149/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 150/300
# 30/30 - 0s - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 151/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 152/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 153/300
# 30/30 - 0s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 154/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 155/300
# 30/30 - 0s - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 156/300
# 30/30 - 0s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 157/300
# 30/30 - 0s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 158/300
# 30/30 - 0s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 159/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 160/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 161/300
# 30/30 - 0s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 162/300
# 30/30 - 0s - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 163/300
# 30/30 - 0s - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 164/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 165/300
# 30/30 - 0s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 166/300
# 30/30 - 0s - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 167/300
# 30/30 - 0s - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 168/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 169/300
# 30/30 - 0s - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 170/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 171/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 172/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 173/300
# 30/30 - 0s - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 174/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 175/300
# 30/30 - 0s - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 176/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 177/300
# 30/30 - 0s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 178/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 179/300
# 30/30 - 0s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 180/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 181/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 182/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 183/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 184/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 185/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 186/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 187/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 188/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 189/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 190/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 191/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 192/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 193/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 194/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 195/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 196/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 197/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 198/300
# 30/30 - 0s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 199/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 200/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 201/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 202/300
# 30/30 - 0s - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 203/300
# 30/30 - 0s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 204/300
# 30/30 - 0s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 205/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 206/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 207/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 208/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 209/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 210/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 211/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 212/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 213/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 214/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 215/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 216/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 217/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 218/300
# 30/30 - 0s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 219/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 220/300
# 30/30 - 0s - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 221/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 222/300
# 30/30 - 0s - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 223/300
# 30/30 - 0s - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 224/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 225/300
# 30/30 - 0s - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 226/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 227/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 228/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 229/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 230/300
# 30/30 - 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 231/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 232/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 233/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 234/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 235/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 236/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 237/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 238/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 239/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 240/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 241/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 242/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 243/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 244/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 245/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 246/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 247/300
# 30/30 - 0s - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 248/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 249/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 250/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 251/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 252/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 253/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 254/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 255/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 256/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 257/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 258/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 259/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 260/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 261/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 262/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 263/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 264/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 265/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 266/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 267/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 268/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 269/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 270/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 271/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 272/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 273/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 274/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 275/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 276/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 277/300
# 30/30 - 0s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 278/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 279/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 280/300
# 30/30 - 0s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 281/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 282/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 283/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 284/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 285/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 286/300
# 30/30 - 0s - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 287/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 288/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 289/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 290/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 291/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 292/300
# 30/30 - 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 293/300
# 30/30 - 0s - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 294/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 295/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 296/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 297/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 298/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 299/300
# 30/30 - 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 300/300
# 30/30 - 0s - loss: 0.0056 - mean_squared_error: 0.0056

# %%
print('Mean squared error on develpment set is: {}'.format(model.evaluate([avg_vectors_sent1_dev,avg_vectors_sent2_dev],scores_dev)[1]))
# Out:
#  1/32 [..............................] - ETA: 0s - loss: 0.0703 - mean_squared_error: 0.0703
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0707 - mean_squared_error: 0.0707
# Mean squared error on develpment set is: 0.07066523283720016
